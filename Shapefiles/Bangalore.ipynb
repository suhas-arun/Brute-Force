# %%
import geopandas

# %%
buildings = geopandas.read_file("Bangalore/buildings/buildings.shp")
buildings.plot()

# %%
landuse = geopandas.read_file("Bangalore/landuse/landuse.shp")
landuse.plot()

# %%
natural = geopandas.read_file("Bangalore/natural/natural.shp")
natural.plot()

# %%
railways = geopandas.read_file("Bangalore/railways/railways.shp")
railways.plot()

# %%
waterways = geopandas.read_file("Bangalore/waterways/waterways.shp")
waterways.plot()

# %%
city = landuse.plot(color="grey")
natural.plot(ax=city, color="green")
waterways.plot(ax=city, color="blue")
