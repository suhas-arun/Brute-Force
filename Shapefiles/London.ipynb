# %%
import geopandas

# %%
buildings = geopandas.read_file("London/buildings/buildings.shp")
buildings.plot()

# %%
landuse = geopandas.read_file("London/landuse/landuse.shp")
landuse.plot()

# %%
natural = geopandas.read_file("London/natural/natural.shp")
natural.plot()

# %%
railways = geopandas.read_file("London/railways/railways.shp")
railways.plot()

# %%
waterways = geopandas.read_file("London/waterways/waterways.shp")
waterways.plot()

# %%
city = landuse.plot(color="grey")
natural.plot(ax=city, color="green")
waterways.plot(ax=city, color="blue")
