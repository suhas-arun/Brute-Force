# %%
import geopandas

# %%
landuse = geopandas.read_file("NewYork/landuse/landuse.shp")
landuse.plot()

# %%
natural = geopandas.read_file("NewYork/natural/natural.shp")
natural.plot()

# %%
railways = geopandas.read_file("NewYork/railways/railways.shp")
railways.plot()

# %%
waterways = geopandas.read_file("NewYork/waterways/waterways.shp")
waterways.plot()

# %%
city = landuse.plot(color="grey")
natural.plot(ax=city, color="green")
waterways.plot(ax=city, color="blue")
