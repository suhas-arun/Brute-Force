# %%
import geopandas

# %%
buildings = geopandas.read_file("Melbourne/buildings/buildings.shp")
buildings.plot()

# %%
landuse = geopandas.read_file("Melbourne/landuse/landuse.shp")
landuse.plot()

# %%
natural = geopandas.read_file("Melbourne/natural/natural.shp")
natural.plot()

# %%
railways = geopandas.read_file("Melbourne/railways/railways.shp")
railways.plot()

# %%
waterways = geopandas.read_file("Melbourne/waterways/waterways.shp")
waterways.plot()

# %%
city = landuse.plot(color="grey")
natural.plot(ax=city, color="green")
waterways.plot(ax=city, color="blue")
